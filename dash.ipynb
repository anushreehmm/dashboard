# %%
import dash
from dash import dcc, html
import plotly.express as px
import dash_bootstrap_components as dbc
from dash.dependencies import Input, Output
import pandas as pd
import json
import glob
import os

# Load the config from the JSON file
with open('dash.json', 'r') as f:
    config = json.load(f)

thresholds = config['service_agreements']

# Data cleaning function
def clean_data(file_path):
    df = pd.read_csv(file_path)
    df = df.drop([0, 1, 2, 3, 4], axis=0)
    df = df.reset_index(drop=True)
    df = df.drop(columns=['Unnamed: 2', 'Unnamed: 3'])
    df = df.rename(columns={
        'Unnamed: 0': 'Host_name', 
        'Unnamed: 1': 'IP_address', 
        'Unnamed: 4': 'Availability-%', 
        'Unnamed: 5': 'Latency(msec)', 
        'Unnamed: 6': 'Packetloss(%)'
    })
    df['Packetloss(%)'] = pd.to_numeric(df['Packetloss(%)'], errors='coerce')
    df['Availability-%'] = pd.to_numeric(df['Availability-%'], errors='coerce')
    df['Latency(msec)'] = pd.to_numeric(df['Latency(msec)'], errors='coerce')
    df = df.dropna(subset=['Packetloss(%)', 'Availability-%', 'Latency(msec)'])
    return df

# Folder containing CSV files
folder_path = r'C:\Users\AnushreeHM\Downloads\ibus'

# Get list of all CSV files in the folder
file_list = glob.glob(os.path.join(folder_path, '*.csv'))

# Load and clean each file
dataframes = [clean_data(file_path) for file_path in file_list]

# Combine all DataFrames into one
df = pd.concat(dataframes, ignore_index=True)

# Dash App setup
app = dash.Dash(__name__, external_stylesheets=[dbc.themes.CYBORG])

# List of unique hostnames for dropdown filter
hostnames = df['Host_name'].unique()

app.layout = dbc.Container(
    [
        dbc.Row([
            dbc.Col(html.H1("Network Metrics Dashboard", style={"text-align": "center", "margin-top": "20px"}), width=12),
        ]),
        dbc.Row([
            dbc.Col([
                html.Label("Filter by Host Name:", style={"margin-top": "20px"}),
                dcc.Dropdown(
                    id='hostname-dropdown',
                    options=[{'label': name, 'value': name} for name in hostnames],
                    multi=True,
                    value=hostnames[:5],
                    placeholder="Select Hostnames",
                    style={"color": "#000"}
                ),
            ], width=12),
        ]),
        dbc.Row([
            dbc.Col(
                dcc.Graph(id='packet-loss-graph'), 
                width=6
            ),
            dbc.Col(
                dcc.Graph(id='latency-graph'), 
                width=6
            ),
        ], style={"margin-top": "30px"}),
        dbc.Row([
            dbc.Col(
                dcc.Graph(id='availability-graph'), 
                width=12
            ),
        ], style={"margin-top": "30px", "margin-bottom": "30px"}),
    ], 
    fluid=True
)

# Functions for color mapping based on thresholds from the config
def get_packet_loss_color(value, service='taj'):
    thresholds = config['service_agreements'][service]['packet_loss_threshold']
    if value > thresholds['critical']:
        return 'red'
    elif value > thresholds['warning']:
        return 'orange'
    elif value > thresholds['caution']:
        return 'yellow'
    else:
        return 'green'

def get_latency_color(value, service='taj'):
    thresholds = config['service_agreements'][service]['latency_threshold']
    if value > thresholds['critical']:
        return 'red'
    elif value > thresholds['warning']:
        return 'orange'
    elif value > thresholds['caution']:
        return 'yellow'
    else:
        return 'green'

def get_availability_color(value, service='taj'):
    thresholds = config['service_agreements'][service]['availability_threshold']
    if value > thresholds['critical']:
        return 'red'
    elif value > thresholds['warning']:
        return 'orange'
    elif value > thresholds['caution']:
        return 'yellow'
    else:
        return 'green'

# Callback function to update graphs dynamically based on dropdown selection
@app.callback(
    [Output('packet-loss-graph', 'figure'),
     Output('latency-graph', 'figure'),
     Output('availability-graph', 'figure')],
    [Input('hostname-dropdown', 'value')]
)
def update_graphs(selected_hostnames):
    filtered_df = df[df['Host_name'].isin(selected_hostnames)]

    # Packet Loss Graph
    packet_loss_fig = px.bar(
        filtered_df,
        x="Host_name",
        y="Packetloss(%)",
        title="Packet Loss Percentage by Host Name",
        labels={"Packetloss(%)": "Packet Loss (%)"},
        template="plotly_dark",
        color="Packetloss(%)",
        color_continuous_scale=["green", "yellow", "orange", "red"],
    )
    packet_loss_fig.update_layout(margin={"l": 40, "r": 20, "t": 40, "b": 30})

    # Latency Graph
    latency_fig = px.bar(
        filtered_df,
        x="Host_name",
        y="Latency(msec)",
        title="Latency by Host Name",
        labels={"Latency(msec)": "Latency (ms)"},
        template="plotly_dark",
        color="Latency(msec)",
        color_continuous_scale=["green", "yellow", "orange", "red"],
    )
    latency_fig.update_layout(margin={"l": 40, "r": 20, "t": 40, "b": 30})

    # Availability Graph
    availability_fig = px.bar(
        filtered_df,
        x="Host_name",
        y="Availability-%",
        title="Availability by Host Name",
        labels={"Availability-%": "Availability (%)"},
        template="plotly_dark",
        color="Availability-%",
        color_continuous_scale=["red", "orange", "yellow", "green"],
    )
    availability_fig.update_layout(margin={"l": 40, "r": 20, "t": 40, "b": 30})

    return packet_loss_fig, latency_fig, availability_fig

if __name__ == '__main__':
    app.run_server(debug=True, port='8054')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import dash
#       2 from dash import dcc, html
#       3 import plotly.express as px
#
# File ~\anaconda3\dashboard\dash.py:8
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "c4a38214-a731-4bf5-b136-ffdee6ead468",
#       7    "metadata": {
# ----> 8     "scrolled": true
#       9    },
#      10    "outputs": [
#      11     {
#      12      "data": {
#      13       "text/html": [
#      14        "\n",
#      15        "        <iframe\n",
#      16        "            width=\"100%\"\n",
#      17        "            height=\"650\"\n",
#      18        "            src=\"http://127.0.0.1:8054/\"\n",
#      19        "            frameborder=\"0\"\n",
#      20        "            allowfullscreen\n",
#      21        "            \n",
#      22        "        ></iframe>\n",
#      23        "        "
#      24       ],
#      25       "text/plain": [
#      26        "<IPython.lib.display.IFrame at 0x2591459f500>"
#      27       ]
#      28      },
#      29      "metadata": {},
#      30      "output_type": "display_data"
#      31     }
#      32    ],
#      33    "source": [
#      34     "import dash\n",
#      35     "from dash import dcc, html\n",
#      36     "import plotly.express as px\n",
#      37     "import dash_bootstrap_components as dbc\n",
#      38     "from dash.dependencies import Input, Output\n",
#      39     "import pandas as pd\n",
#      40     "import json\n",
#      41     "import glob\n",
#      42     "import os\n",
#      43     "\n",
#      44     "# Load the config from the JSON file\n",
#      45     "with open('dash.json', 'r') as f:\n",
#      46     "    config = json.load(f)\n",
#      47     "\n",
#      48     "thresholds = config['service_agreements']\n",
#      49     "\n",
#      50     "# Data cleaning function\n",
#      51     "def clean_data(file_path):\n",
#      52     "    df = pd.read_csv(file_path)\n",
#      53     "    df = df.drop([0, 1, 2, 3, 4], axis=0)\n",
#      54     "    df = df.reset_index(drop=True)\n",
#      55     "    df = df.drop(columns=['Unnamed: 2', 'Unnamed: 3'])\n",
#      56     "    df = df.rename(columns={\n",
#      57     "        'Unnamed: 0': 'Host_name', \n",
#      58     "        'Unnamed: 1': 'IP_address', \n",
#      59     "        'Unnamed: 4': 'Availability-%', \n",
#      60     "        'Unnamed: 5': 'Latency(msec)', \n",
#      61     "        'Unnamed: 6': 'Packetloss(%)'\n",
#      62     "    })\n",
#      63     "    df['Packetloss(%)'] = pd.to_numeric(df['Packetloss(%)'], errors='coerce')\n",
#      64     "    df['Availability-%'] = pd.to_numeric(df['Availability-%'], errors='coerce')\n",
#      65     "    df['Latency(msec)'] = pd.to_numeric(df['Latency(msec)'], errors='coerce')\n",
#      66     "    df = df.dropna(subset=['Packetloss(%)', 'Availability-%', 'Latency(msec)'])\n",
#      67     "    return df\n",
#      68     "\n",
#      69     "# Folder containing CSV files\n",
#      70     "folder_path = r'C:\\Users\\AnushreeHM\\Downloads\\ibus'\n",
#      71     "\n",
#      72     "# Get list of all CSV files in the folder\n",
#      73     "file_list = glob.glob(os.path.join(folder_path, '*.csv'))\n",
#      74     "\n",
#      75     "# Load and clean each file\n",
#      76     "dataframes = [clean_data(file_path) for file_path in file_list]\n",
#      77     "\n",
#      78     "# Combine all DataFrames into one\n",
#      79     "df = pd.concat(dataframes, ignore_index=True)\n",
#      80     "\n",
#      81     "# Dash App setup\n",
#      82     "app = dash.Dash(__name__, external_stylesheets=[dbc.themes.CYBORG])\n",
#      83     "\n",
#      84     "# List of unique hostnames for dropdown filter\n",
#      85     "hostnames = df['Host_name'].unique()\n",
#      86     "\n",
#      87     "app.layout = dbc.Container(\n",
#      88     "    [\n",
#      89     "        dbc.Row([\n",
#      90     "            dbc.Col(html.H1(\"Network Metrics Dashboard\", style={\"text-align\": \"center\", \"margin-top\": \"20px\"}), width=12),\n",
#      91     "        ]),\n",
#      92     "        dbc.Row([\n",
#      93     "            dbc.Col([\n",
#      94     "                html.Label(\"Filter by Host Name:\", style={\"margin-top\": \"20px\"}),\n",
#      95     "                dcc.Dropdown(\n",
#      96     "                    id='hostname-dropdown',\n",
#      97     "                    options=[{'label': name, 'value': name} for name in hostnames],\n",
#      98     "                    multi=True,\n",
#      99     "                    value=hostnames[:5],\n",
#     100     "                    placeholder=\"Select Hostnames\",\n",
#     101     "                    style={\"color\": \"#000\"}\n",
#     102     "                ),\n",
#     103     "            ], width=12),\n",
#     104     "        ]),\n",
#     105     "        dbc.Row([\n",
#     106     "            dbc.Col(\n",
#     107     "                dcc.Graph(id='packet-loss-graph'), \n",
#     108     "                width=6\n",
#     109     "            ),\n",
#     110     "            dbc.Col(\n",
#     111     "                dcc.Graph(id='latency-graph'), \n",
#     112     "                width=6\n",
#     113     "            ),\n",
#     114     "        ], style={\"margin-top\": \"30px\"}),\n",
#     115     "        dbc.Row([\n",
#     116     "            dbc.Col(\n",
#     117     "                dcc.Graph(id='availability-graph'), \n",
#     118     "                width=12\n",
#     119     "            ),\n",
#     120     "        ], style={\"margin-top\": \"30px\", \"margin-bottom\": \"30px\"}),\n",
#     121     "    ], \n",
#     122     "    fluid=True\n",
#     123     ")\n",
#     124     "\n",
#     125     "# Functions for color mapping based on thresholds from the config\n",
#     126     "def get_packet_loss_color(value, service='taj'):\n",
#     127     "    thresholds = config['service_agreements'][service]['packet_loss_threshold']\n",
#     128     "    if value > thresholds['critical']:\n",
#     129     "        return 'red'\n",
#     130     "    elif value > thresholds['warning']:\n",
#     131     "        return 'orange'\n",
#     132     "    elif value > thresholds['caution']:\n",
#     133     "        return 'yellow'\n",
#     134     "    else:\n",
#     135     "        return 'green'\n",
#     136     "\n",
#     137     "def get_latency_color(value, service='taj'):\n",
#     138     "    thresholds = config['service_agreements'][service]['latency_threshold']\n",
#     139     "    if value > thresholds['critical']:\n",
#     140     "        return 'red'\n",
#     141     "    elif value > thresholds['warning']:\n",
#     142     "        return 'orange'\n",
#     143     "    elif value > thresholds['caution']:\n",
#     144     "        return 'yellow'\n",
#     145     "    else:\n",
#     146     "        return 'green'\n",
#     147     "\n",
#     148     "def get_availability_color(value, service='taj'):\n",
#     149     "    thresholds = config['service_agreements'][service]['availability_threshold']\n",
#     150     "    if value > thresholds['critical']:\n",
#     151     "        return 'red'\n",
#     152     "    elif value > thresholds['warning']:\n",
#     153     "        return 'orange'\n",
#     154     "    elif value > thresholds['caution']:\n",
#     155     "        return 'yellow'\n",
#     156     "    else:\n",
#     157     "        return 'green'\n",
#     158     "\n",
#     159     "# Callback function to update graphs dynamically based on dropdown selection\n",
#     160     "@app.callback(\n",
#     161     "    [Output('packet-loss-graph', 'figure'),\n",
#     162     "     Output('latency-graph', 'figure'),\n",
#     163     "     Output('availability-graph', 'figure')],\n",
#     164     "    [Input('hostname-dropdown', 'value')]\n",
#     165     ")\n",
#     166     "def update_graphs(selected_hostnames):\n",
#     167     "    filtered_df = df[df['Host_name'].isin(selected_hostnames)]\n",
#     168     "\n",
#     169     "    # Packet Loss Graph\n",
#     170     "    packet_loss_fig = px.bar(\n",
#     171     "        filtered_df,\n",
#     172     "        x=\"Host_name\",\n",
#     173     "        y=\"Packetloss(%)\",\n",
#     174     "        title=\"Packet Loss Percentage by Host Name\",\n",
#     175     "        labels={\"Packetloss(%)\": \"Packet Loss (%)\"},\n",
#     176     "        template=\"plotly_dark\",\n",
#     177     "        color=\"Packetloss(%)\",\n",
#     178     "        color_continuous_scale=[\"green\", \"yellow\", \"orange\", \"red\"],\n",
#     179     "    )\n",
#     180     "    packet_loss_fig.update_layout(margin={\"l\": 40, \"r\": 20, \"t\": 40, \"b\": 30})\n",
#     181     "\n",
#     182     "    # Latency Graph\n",
#     183     "    latency_fig = px.bar(\n",
#     184     "        filtered_df,\n",
#     185     "        x=\"Host_name\",\n",
#     186     "        y=\"Latency(msec)\",\n",
#     187     "        title=\"Latency by Host Name\",\n",
#     188     "        labels={\"Latency(msec)\": \"Latency (ms)\"},\n",
#     189     "        template=\"plotly_dark\",\n",
#     190     "        color=\"Latency(msec)\",\n",
#     191     "        color_continuous_scale=[\"green\", \"yellow\", \"orange\", \"red\"],\n",
#     192     "    )\n",
#     193     "    latency_fig.update_layout(margin={\"l\": 40, \"r\": 20, \"t\": 40, \"b\": 30})\n",
#     194     "\n",
#     195     "    # Availability Graph\n",
#     196     "    availability_fig = px.bar(\n",
#     197     "        filtered_df,\n",
#     198     "        x=\"Host_name\",\n",
#     199     "        y=\"Availability-%\",\n",
#     200     "        title=\"Availability by Host Name\",\n",
#     201     "        labels={\"Availability-%\": \"Availability (%)\"},\n",
#     202     "        template=\"plotly_dark\",\n",
#     203     "        color=\"Availability-%\",\n",
#     204     "        color_continuous_scale=[\"red\", \"orange\", \"yellow\", \"green\"],\n",
#     205     "    )\n",
#     206     "    availability_fig.update_layout(margin={\"l\": 40, \"r\": 20, \"t\": 40, \"b\": 30})\n",
#     207     "\n",
#     208     "    return packet_loss_fig, latency_fig, availability_fig\n",
#     209     "\n",
#     210     "if __name__ == '__main__':\n",
#     211     "    app.run_server(debug=True, port='8054')\n"
#     212    ]
#     213   },
#     214   {
#     215    "cell_type": "code",
#     216    "execution_count": null,
#     217    "id": "e46d669b-dc74-479e-a05b-99962831f41a",
#     218    "metadata": {},
#     219    "outputs": [],
#     220    "source": []
#     221   }
#     222  ],
#     223  "metadata": {
#     224   "kernelspec": {
#     225    "display_name": "Python 3 (ipykernel)",
#     226    "language": "python",
#     227    "name": "python3"
#     228   },
#     229   "language_info": {
#     230    "codemirror_mode": {
#     231     "name": "ipython",
#     232     "version": 3
#     233    },
#     234    "file_extension": ".py",
#     235    "mimetype": "text/x-python",
#     236    "name": "python",
#     237    "nbconvert_exporter": "python",
#     238    "pygments_lexer": "ipython3",
#     239    "version": "3.12.4"
#     240   }
#     241  },
#     242  "nbformat": 4,
#     243  "nbformat_minor": 5
#     244 }
#
# NameError: name 'true' is not defined
